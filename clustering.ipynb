# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('app_users.csv', index_col = [0])
df.head()
# Out:
#    visit_per_month  use_time
# 0               14      22.8
# 1               32      13.6
# 2                8       3.1
# 3               13       5.7
# 4               19      20.8

# %%
sns.set(style='darkgrid', 
        rc={'figure.figsize':(12,8)})

sns.scatterplot(x='visit_per_month', y='use_time', data=df, s=100, palette='bright')
# Out:
# C:\Users\test\AppData\Local\Temp\ipykernel_20084\31183472.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x='visit_per_month', y='use_time', data=df, s=100, palette='bright')
# <Axes: xlabel='visit_per_month', ylabel='use_time'>
